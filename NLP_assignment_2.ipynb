# %% [markdown]
# #1. Create a Doc object from the file owlcreek.txt:

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

with open("owlcreek.txt", "r", encoding="utf-8") as f:
    text = f.read()

doc = nlp(text)
print([token.text for token in doc[:10]])
# Out:
# ['AN', 'OCCURRENCE', 'AT', 'OWL', 'CREEK', 'BRIDGE', '\n\n', 'by', 'Ambrose', 'Bierce']

# %% [markdown]
# #2. How many tokens are contained in the file?

# %%
num_token=len(doc)
print("Number of Token in the file:",num_token)
# Out:
# Number of Token in the file: 4835

# %% [markdown]
# #3. How many sentences are contained in the file?

# %%
num_sentences=len(list(doc.sents))
print("Number of sentences in files:",num_sentences)
# Out:
# Number of sentences in files: 204

# %% [markdown]
# #4. Print the second sentence in the document

# %%
sentences=list(doc.sents)
print(sentences[1].text)
# Out:
# The man's hands were behind
# his back, the wrists bound with a cord.

# %% [markdown]
# #5. For each token in the sentence above, print its text, POS tag, dep tag and lemma.

# %%
sentences=list(doc.sents)
third_sentence=sentences[2]

for token in third_sentence:
  print({token.text}, {token.pos_}, {token.dep_}, {token.lemma_})
# Out:
# {'A'} {'DET'} {'det'} {'a'}
# {'rope'} {'NOUN'} {'nsubj'} {'rope'}
# {'closely'} {'ADV'} {'advmod'} {'closely'}
# {'encircled'} {'VERB'} {'ROOT'} {'encircle'}
# {'his'} {'PRON'} {'poss'} {'his'}
# {'\n'} {'SPACE'} {'dep'} {'\n'}
# {'neck'} {'NOUN'} {'dobj'} {'neck'}
# {'.'} {'PUNCT'} {'punct'} {'.'}
# {' '} {'SPACE'} {'dep'} {' '}

# %% [markdown]
# 6. Write a matcher called 'Swimming' that finds both occurrences of the phrase "swimming vigorously" in the text.

# %%
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab)
pattern = [
    {"LOWER": "swimming"},
    {"LOWER": "vigorously"}
]


matcher.add("Swimming", [pattern])
matches = matcher(doc)

for match_id, start, end in matches:
    span = doc[start:end]
    print("Match found:", span.text)

# %% [markdown]
# #7. Print the text surrounding each found match.

# %%
matches = matcher(doc)

for match_id, start, end in matches:
    span = doc[start:end]
    sentence = span.sent
    print("Match:", span.text)
    print("Sentence context:", sentence.text)
    print("---")
